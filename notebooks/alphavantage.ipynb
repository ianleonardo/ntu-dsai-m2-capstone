# %%
import os
import requests
from dotenv import load_dotenv

# Load environment variables to get VANTAGE_API_KEY
load_dotenv()
api_key = os.getenv('VANTAGE_API_KEY')

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=RSI&symbol=IBM&interval=weekly&time_period=10&series_type=open&apikey={VANTAGE_API_KEY}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Load environment variables to get VANTAGE_API_KEY
#       5 load_dotenv()
# ----> 6 api_key = os.getenv('VANTAGE_API_KEY')
#       8 # replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
#       9 url = f'https://www.alphavantage.co/query?function=RSI&symbol=IBM&interval=weekly&time_period=10&series_type=open&apikey={VANTAGE_API_KEY}'
#
# NameError: name 'os' is not defined
